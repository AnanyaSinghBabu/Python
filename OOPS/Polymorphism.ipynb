# %% [markdown]
# Polymorphism allows methods to have the same name but behave differently based on the object's context.
#
# It can be achieved through method overriding or overloading.

# %% [markdown]
#  The word "polymorphism" means "many forms", and in programming it refers to methods/functions/operators with the same name that can be executed on many objects or classes.
#
#  Technically, in Python, polymorphism allows same method, function or operator to behave differently depending on object it is working with. This makes code more flexible and reusable.

# %% [markdown]
#     Method Overriding (Polymorphism with Inheritance):
#
# When a subclass provides its own specific implementation of a method that is already defined in its superclass, it's called method overriding.

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

# Create object of child class
d = Dog()
d.sound()
# Out:
# Dog barks

# %%
# Method Overriding (Polymorphism with Inheritance)

class Animal:
    def speak(self):
        return "Some generic animal sound"

class Dog(Animal):
    def speak(self):  # Overriding the speak method
        return "Woof!"

class Cat(Animal):
    def speak(self):  # Overriding the speak method
        return "Meow!"

animal_objects = [Dog(), Cat(), Animal()]

for animal in animal_objects:
    print(animal.speak())
# Out:
# Woof!
# Meow!
# Some generic animal sound

# %% [markdown]
#     Operator Overloading:
#
# Python allows you to redefine how standard operators (like +, -, *, etc.) behave for custom classes. This is a form of polymorphism because the same operator can have different meanings based on the types of operands.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):  # Overloading the + operator
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(1, 2)
v2 = Vector(3, 4)

v3 = v1 + v2  # Uses the overloaded __add__ method
print(v3)    # Output: Vector(4, 6)

print(10 + 20) # Standard integer addition
print("Hello" + " World") # Standard string concatenation
# Out:
# Vector(4, 6)
# 30
# Hello World

# %%
class Animal:
    def sound(self):
        return "Some sound"

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):           # All classes have the same method sound()
        return "Meow"          # but each class defines it differently

# Polymorphism in action
animals = [Dog(), Cat(), Animal()]

for animal in animals:
    print(animal.sound())
# Out:
# Bark
# Meow
# Some sound

# %%
class Duck:
    def talk(self):
        print("Quack!")

class Human:
    def talk(self):
        print("Hello!")

def call_talk(obj):
    obj.talk()

call_talk(Duck())   
call_talk(Human())  

# Both Duck and Human have a method talk().
# The function call_talk() works on any object that has a talk() method.
# Python doesn’t care about the class type — “If it talks like a duck, it’s a duck.”
# Out:
# Quack!
# Hello!

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Airplane:
    def fly(self):
        print("Airplane can fly")

class Fish:
    def swim(self):
        print("Fish can swim")

# Polymorphic function
def let_it_fly(obj):
    obj.fly()

b = Bird()
a = Airplane()

let_it_fly(b)  
let_it_fly(a)  

#The function let_it_fly() works with any object that has a fly() method —
# this is called Duck Typing in Python:

"If it looks like a duck and quacks like a duck, it's a duck!"
# Out:
# Bird can fly
# Airplane can fly
