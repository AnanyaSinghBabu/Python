# %% [markdown]
#     Data Manipulation and Analysis with Pandas:
# Data manipulation and analysis are key tasks in any data science or data analysis project. Pandas provides a wide range of functions for data manipulation and analysis, making it easier to clean, transform, and extract insights from data. In this lesson, we will cover various data manipulation and analysis techniques using Pandas.

# %%
import pandas as pd

# %%
df=pd.read_csv('Netflix Dataset.csv')

# %%
df.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.describe()
# Out:
#        Show_Id Category     Title                Director                Cast  \
# count     7789     7789      7789                    5401                7071
# unique    7787        2      7787                    4050                6831
# top       s684    Movie  Backfire  Raúl Campos, Jan Suter  David Attenborough
# freq         2     5379         2                      18                  18
#
#               Country     Release_Date Rating  Duration           Type  \
# count            7282             7779   7782      7789           7789
# unique            681             1565     14       216            492
# top     United States  January 1, 2020  TV-MA  1 Season  Documentaries
# freq             2556              118   2865      1608            334
#
#                                               Description
# count                                                7789
# unique                                               7769
# ...

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
## Handling Missing Values
df.isnull().any()
# Out:
# Show_Id         False
# Category        False
# Title           False
# Director         True
# Cast             True
# Country          True
# Release_Date     True
# Rating           True
# Duration        False
# Type            False
# Description     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df_filled=df.fillna(0)

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df.sort_values("Release_Date", ascending=False).head(10)
# Out:
#      Show_Id Category                                    Title  \
# 6885   s6884    Movie                       The Social Dilemma
# 1217   s1218    Movie                                    Cargo
# 5686   s5686    Movie                     So Much Love to Give
# 1559   s1560    Movie                                   Cuties
# 3496   s3497  TV Show                La Línea: Shadow of Narco
# 2385   s2386  TV Show         Get Organized with The Home Edit
# 4509   s4510    Movie  Norm of the North: King Sized Adventure
# 5587   s5587  TV Show                        Show Me the Money
# 3121   s3122    Movie               Jandino: Whatever it Takes
# 2295   s2296    Movie                     From Paris with Love
#
#                       Director  \
# 6885             Jeff Orlowski
# 1217               Arati Kadav
# 5686          Marcos Carnevale
# 1559         Maïmouna Doucouré
# 3496                 Pepe Mora
# 2385                       NaN
# 4509  Richard Finn, Tim Maltby
# ...

# %%
df.duplicated().sum()          # how many duplicate rows
# Out:
# np.int64(2)

# %%
df.sort_values("Release_Date").head(1)    # oldest show/movie
# Out:
#      Show_Id Category                Title Director Cast Country  \
# 6673   s6672  TV Show  The Minimighty Kids      NaN  NaN  France
#
#          Release_Date Rating   Duration                   Type  \
# 6673   April 15, 2018   TV-G  2 Seasons  Kids' TV, TV Comedies
#
#                                             Description
# 6673  Some have big feet or a sniffly nose, others a...

# %%
df.sort_values("Release_Date").tail(1)    # newest show/movie
# Out:
#      Show_Id Category                         Title Director  \
# 6066   s6066  TV Show  The Adventures of Figaro Pho      NaN
#
#                                                    Cast    Country  \
# 6066  Luke Jurevicius, Craig Behenna, Charlotte Haml...  Australia
#
#      Release_Date Rating   Duration                   Type  \
# 6066          NaN  TV-Y7  2 Seasons  Kids' TV, TV Comedies
#
#                                             Description
# 6066  Imagine your worst fears, then multiply them: ...
